# %% [raw]
# I can solve a system with second derivatives by converting to a first order system.
# Most tools other than Mathematica will need you to do this.
# Here is he orbit problem from #11 on p163 of Dormand Numerical Methdos for ODEs by John Dormand
# $$
# \begin{aligned}
# x'' &= 2 y' + x - \frac{E(x+M)}{r_1^3} -\frac{M(x-E)}{r_2^3} \\
# y'' &= -2 x' + y - \frac{E y}{r_1^3}-\frac{M y}{r_2^3}
#     \end{aligned}
# $$
# with for the Earth Moon System $M=1/82.45$ and $E=1-M$ and
# $$
# \begin{aligned}
# r_1 &= \sqrt{(x+M)^2 + y^2}\\
# r_2 &= \sqrt{(x-E)^2 + y^2}\\
# \end{aligned}
# $$
# The intention is to solve this system with some specified initial conditions.

# %%
using DifferentialEquations, Plots

function dormand!(du, u, p, t)
# Constants for the Earth-Moon system
const μ = 1/82.45
const μ2 = 1 - μ

# The ODE function for the Earth-Moon probe system
# The state vector u is [x, y, vx, vy]
function earth_moon_probe!(du, u, p, t)
    # Unpack the state variables
    x, y, vx, vy = u

    # Distances to the Earth and Moon
    r1_sq = (x + μ2)^2 + y^2
    r2_sq = (x - μ)^2 + y^2
    r1_cubed = r1_sq^(3/2)
    r2_cubed = r2_sq^(3/2)

    # Define the derivatives
    du[1] = vx
    du[2] = vy
    du[3] = x + 2vy - μ * (x + μ2) / r1_cubed - μ2 * (x - μ) / r2_cubed
    du[4] = y - 2vx - μ * y / r1_cubed - μ2 * y / r2_cubed
    return nothing
end

# Define the initial conditions
# Initial position (x, y) and velocity (vx, vy) for a specific trajectory
# Example initial conditions (from a common setup for this problem)
u0 = [1.2, 0.0, 0.0, -1.049357509830320]
tspan = (0.0, 6.192169331319640)

# Create and solve the ODE problem using a Dormand-Prince solver (a common choice for adaptive RK methods)
# The `Vern9()` solver is a good high-order adaptive method.
prob = ODEProblem(earth_moon_probe!, u0, tspan)
sol = solve(prob, Vern9(), reltol=1e-12, abstol=1e-12)

# Extract x and y coordinates from the solution for plotting
x_probe = [u[1] for u in sol.u]
y_probe = [u[2] for u in sol.u]

# Define positions for Earth and Moon (in the rotating frame)
x_earth = -μ
y_earth = 0.0
x_moon = 1 - μ
y_moon = 0.0

# Plot the results
plt = plot(aspect_ratio=:equal, title="Earth-Moon Probe Trajectory", legend=:topright)

# Plot the probe's trajectory
plot!(plt, x_probe, y_probe, label="Probe Trajectory", color=:blue, lw=2)

# Plot Earth and Moon as circles
scatter!(plt, [x_earth], [y_earth], markersize=10, markercolor=:blue, label="Earth")
scatter!(plt, [x_moon], [y_moon], markersize=5, markercolor=:grey, label="Moon")

# Add labels and limits
xlabel!("x-position")
ylabel!("y-position")
xlims!(-1.5, 1.5)
ylims!(-1.5, 1.5)

# Display the plot
display(plt)
# Out:
# [ Info: Precompiling DifferentialEquations [0c46a032-eb83-5123-abaf-570d42b7fbaa]
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2399
# │     [30] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [31] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [32] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [33] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [34] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [35] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [36] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [37] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [38] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [39] include
# │        @ .\Base.jl:562 [inlined]
# │     [40] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [41] top-level scope
# │        @ stdin:6
# │     [42] eval
# │        @ .\boot.jl:430 [inlined]
# │     [43] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [44] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [45] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [46] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _tryrequire_from_serialized(modkey::Base.PkgId, build_id::UInt128)
# │        @ Base .\loading.jl:1890
# │     [30] _tryrequire_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String)
# │        @ Base .\loading.jl:1956
# │     [31] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2594
# │     [32] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [33] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [34] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [35] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [36] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [37] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [38] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [39] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [40] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [41] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [42] include
# │        @ .\Base.jl:562 [inlined]
# │     [43] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [44] top-level scope
# │        @ stdin:6
# │     [45] eval
# │        @ .\boot.jl:430 [inlined]
# │     [46] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [47] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [48] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [49] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2399
# │     [30] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [31] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [32] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [33] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [34] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [35] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [36] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [37] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [38] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [39] include
# │        @ .\Base.jl:562 [inlined]
# │     [40] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [41] top-level scope
# │        @ stdin:6
# │     [42] eval
# │        @ .\boot.jl:430 [inlined]
# │     [43] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [44] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [45] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [46] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _tryrequire_from_serialized(modkey::Base.PkgId, build_id::UInt128)
# │        @ Base .\loading.jl:1890
# │     [30] _tryrequire_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String)
# │        @ Base .\loading.jl:1956
# │     [31] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2594
# │     [32] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [33] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [34] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [35] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [36] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [37] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [38] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [39] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [40] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [41] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [42] include
# │        @ .\Base.jl:562 [inlined]
# │     [43] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [44] top-level scope
# │        @ stdin:6
# │     [45] eval
# │        @ .\boot.jl:430 [inlined]
# │     [46] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [47] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [48] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [49] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _tryrequire_from_serialized(modkey::Base.PkgId, build_id::UInt128)
# │        @ Base .\loading.jl:1890
# │     [30] _tryrequire_from_serialized(pkg::Base.PkgId, path::String, ocachepath::String)
# │        @ Base .\loading.jl:1956
# │     [31] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2594
# │     [32] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [33] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [34] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [35] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [36] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [37] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [38] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [39] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [40] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [41] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [42] include
# │        @ .\Base.jl:562 [inlined]
# │     [43] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::Nothing)
# │        @ Base .\loading.jl:2881
# │     [44] top-level scope
# │        @ stdin:6
# │     [45] eval
# │        @ .\boot.jl:430 [inlined]
# │     [46] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [47] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [48] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [49] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# ...
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
# ┌ Error: Error during loading of extension BracketingNonlinearSolveForwardDiffExt of BracketingNonlinearSolve, use `Base.retry_load_extensions()` to retry.
# │   exception =
# │    1-element ExceptionStack:
# │    IOError: unlink("C:\\Users\\AllanStruthers\\.julia\\compiled\\v1.11\\BracketingNonlinearSolveForwardDiffExt\\ak3V3_Ga1jw.ji"): resource busy or locked (EBUSY)
# │    Stacktrace:
# │      [1] uv_error
# │        @ .\libuv.jl:106 [inlined]
# │      [2] unlink(p::String)
# │        @ Base.Filesystem .\file.jl:1105
# │      [3] rm(path::String; force::Bool, recursive::Bool)
# │        @ Base.Filesystem .\file.jl:283
# │      [4] rm
# │        @ .\file.jl:273 [inlined]
# │      [5] checkfor_mv_cp_cptree(src::String, dst::String, txt::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:332
# │      [6] checkfor_mv_cp_cptree
# │        @ .\file.jl:318 [inlined]
# │      [7] cp(src::String, dst::String; force::Bool, follow_symlinks::Bool)
# │        @ Base.Filesystem .\file.jl:380
# │      [8] cp
# │        @ .\file.jl:378 [inlined]
# │      [9] rename(src::String, dst::String; force::Bool)
# │        @ Base.Filesystem .\file.jl:1114
# │     [10] rename
# │        @ .\file.jl:1110 [inlined]
# │     [11] compilecache(pkg::Base.PkgId, path::String, internal_stderr::IO, internal_stdout::IO, keep_loaded_modules::Bool; flags::Cmd, cacheflags::Base.CacheFlags, reasons::Dict{String, Int64}, loadable_exts::Vector{Base.PkgId})
# │        @ Base .\loading.jl:3161
# │     [12] (::Base.var"#1110#1111"{Base.PkgId})()
# │        @ Base .\loading.jl:2579
# │     [13] mkpidlock(f::Base.var"#1110#1111"{Base.PkgId}, at::String, pid::Int32; kwopts::@Kwargs{stale_age::Int64, wait::Bool})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:95
# │     [14] #mkpidlock#6
# │        @ C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:90 [inlined]
# │     [15] trymkpidlock(::Function, ::Vararg{Any}; kwargs::@Kwargs{stale_age::Int64})
# │        @ FileWatching.Pidfile C:\Users\AllanStruthers\.julia\juliaup\julia-1.11.6+0.x64.w64.mingw32\share\julia\stdlib\v1.11\FileWatching\src\pidfile.jl:116
# │     [16] #invokelatest#2
# │        @ .\essentials.jl:1057 [inlined]
# │     [17] invokelatest
# │        @ .\essentials.jl:1052 [inlined]
# │     [18] maybe_cachefile_lock(f::Base.var"#1110#1111"{Base.PkgId}, pkg::Base.PkgId, srcpath::String; stale_age::Int64)
# │        @ Base .\loading.jl:3698
# │     [19] maybe_cachefile_lock
# │        @ .\loading.jl:3695 [inlined]
# │     [20] _require(pkg::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2565
# │     [21] __require_prelocked(uuidkey::Base.PkgId, env::Nothing)
# │        @ Base .\loading.jl:2388
# │     [22] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [23] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [24] _require_prelocked
# │        @ .\loading.jl:2375 [inlined]
# │     [25] _require_prelocked
# │        @ .\loading.jl:2374 [inlined]
# │     [26] run_extension_callbacks(extid::Base.ExtensionId)
# │        @ Base .\loading.jl:1544
# │     [27] run_extension_callbacks(pkgid::Base.PkgId)
# │        @ Base .\loading.jl:1576
# │     [28] run_package_callbacks(modkey::Base.PkgId)
# │        @ Base .\loading.jl:1396
# │     [29] _require_search_from_serialized(pkg::Base.PkgId, sourcepath::String, build_id::UInt128, stalecheck::Bool; reasons::Dict{String, Int64}, DEPOT_PATH::Vector{String})
# │        @ Base .\loading.jl:2065
# │     [30] _require(pkg::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2527
# │     [31] __require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2388
# │     [32] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [33] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [34] _require_prelocked(uuidkey::Base.PkgId, env::String)
# │        @ Base .\loading.jl:2375
# │     [35] macro expansion
# │        @ .\loading.jl:2314 [inlined]
# │     [36] macro expansion
# │        @ .\lock.jl:273 [inlined]
# │     [37] __require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2271
# │     [38] #invoke_in_world#3
# │        @ .\essentials.jl:1089 [inlined]
# │     [39] invoke_in_world
# │        @ .\essentials.jl:1086 [inlined]
# │     [40] require(into::Module, mod::Symbol)
# │        @ Base .\loading.jl:2260
# │     [41] include
# │        @ .\Base.jl:562 [inlined]
# │     [42] include_package_for_output(pkg::Base.PkgId, input::String, depot_path::Vector{String}, dl_load_path::Vector{String}, load_path::Vector{String}, concrete_deps::Vector{Pair{Base.PkgId, UInt128}}, source::String)
# │        @ Base .\loading.jl:2881
# │     [43] top-level scope
# │        @ stdin:6
# │     [44] eval
# │        @ .\boot.jl:430 [inlined]
# │     [45] include_string(mapexpr::typeof(identity), mod::Module, code::String, filename::String)
# │        @ Base .\loading.jl:2734
# │     [46] include_string
# │        @ .\loading.jl:2744 [inlined]
# │     [47] exec_options(opts::Base.JLOptions)
# │        @ Base .\client.jl:321
# │     [48] _start()
# │        @ Base .\client.jl:531
# └ @ Base loading.jl:1550
